# %%
#抓Stockq的資料
import pandas as pd
url = 'http://www.stockq.org/market/asia.php'
table = pd.read_html(url)[4]
table = table.drop(table.columns[[0,1,2,3,36]],axis=0)
table = table.drop(table.columns[9:296],axis=1)
table
# Out:
#          0         1       2       3         4         5         6       7  \
# 4       股市        指數      漲跌      比例        最高        最低        開盤    今年表現
# 5      紐西蘭   8289.96   17.29   0.21%   8297.05   8268.28   8272.67  -1.29%
# 6     澳洲股市  6119.301  -11.07  -0.18%   6143.60  6119.301   6130.40  -0.78%
# 7    日經225  23794.24   30.87   0.13%  23872.69  23785.70  23854.11   4.52%
# 8     東證一部   1886.38    9.52   0.51%   1890.41   1883.21   1885.15   3.79%
# 9     東證二部   7605.25   60.46   0.80%   7609.91   7568.64   7572.99   4.53%
# 10  JASDAQ    184.72    0.35   0.19%    184.99    184.31     5.43%   13:54
# 11    韓國股市   2517.87    2.06   0.08%   2524.33   2513.09   2519.67   2.04%
# 12    台灣加權  11124.37   52.80   0.48%  11136.06  11095.85  11123.58   4.52%
# 13    台灣店頭    152.88   -0.14  -0.09%    153.91    152.84     2.94%   01/18
# 14    上海綜合  3487.244   12.49   0.36%  3487.244   3448.79   3449.88   5.44%
# ...

# %%
import re
import requests
from bs4 import BeautifulSoup

string = "周杰倫";

url = "https://www.youtube.com/results?search_query=" + string
res = requests.get(url, verify=False)
soup = BeautifulSoup(res.text,'html.parser')
last = None

for entry in soup.select('a'):
    m = re.search("v=(.*)",entry['href'])
    if m:
        target = m.group(1)
        if target == last:
            continue
        if re.search("list",target):
            continue
        last = target
        print(target)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# bTT4lmzlFuE
# 93JPvEFBqLI
# bu7nU9Mhpyo
# DYptgVvkVLQ
# uqPo5Dy-9zI
# YG6jea_EkWg
# 3gJeeF5alBs
# sHD_z90ZKV0
# QwcYGI_CnJw
# d_lyiOhFut4
# DgtnssG6Sks
# JurltUhNHDw
# HuCdi5ZTkJE
# _VxLOj3TB5k
# v3GU9WO5_Aw

# %%
#用python抓Ubike開放資料

import urllib
import gzip
import json
import urllib.request
url = 'https://tcgbusfs.blob.core.windows.net/blobyoubike/YouBikeTP.gz'
with urllib.request.urlopen(url) as response:
    with gzip.GzipFile(fileobj=response) as f:
        jdata = f.read()
        f.close()
        data = json.loads(jdata)
for key,value in data["retVal"].items():
    sno = value["sno"]
    sna = value["sna"]
    mday = value["mday"]
    sbi = value["sbi"]
    bemp= value["bemp"]
    print( "NO." + sno + " " + sna + " " +mday + " " + sbi+ " " +bemp)
# Out:
# NO.0001 捷運市政府站(3號出口) 20180119132932 91 88
# NO.0002 捷運國父紀念館站(2號出口) 20180119132938 18 28
# NO.0003 台北市政府 20180119132913 21 19
# NO.0004 市民廣場 20180119132934 13 45
# NO.0005 興雅國中 20180119132930 41 19
# NO.0006 世貿二館 20170908084345 0 0
# NO.0007 信義廣場(台北101) 20180119132916 27 53
# NO.0008 世貿三館 20180119132935 34 25
# NO.0009 松德站 20180119132933 23 17
# NO.0010 台北市災害應變中心 20180119132930 24 24
# NO.0011 三張犁 20180119132928 55 11
# NO.0012 臺北醫學大學 20180119132934 25 22
# NO.0013 福德公園 20180119132913 25 32
# NO.0014 榮星花園 20180119132920 25 7
# NO.0015 饒河夜市 20180119132935 40 18
# NO.0016 松山家商 20180119132925 8 40
# NO.0017 民生光復路口 20180119132920 19 14
# NO.0018 臺北市藝文推廣處 20180119132937 18 20
# NO.0019 象山公園 20180119132923 18 12
# NO.0020 捷運科技大樓站 20180119132934 41 28
# NO.0021 民生敦化路口 20180119132917 34 32
# NO.0022 松山車站 20180119132913 23 21
# NO.0023 東新國小 20180119132917 15 17
# NO.0024 信義建國路口 20180119132915 8 38
# NO.0025 永吉松信路口 20180119132919 15 15
# NO.0026 捷運昆陽站(1號出口) 20180119132928 22 19
# ...

# %%
#用python抓農產品交易開放資料

import urllib
import gzip
import json
import urllib.request
url = 'http://data.coa.gov.tw/Service/OpenData/FromM/FarmTransData.aspx'
with urllib.request.urlopen(url) as response:
    jdata = response.read()
    data1 = json.loads(jdata)
data=sorted(data1, key=lambda k: k["作物名稱"])
for i in range(0,(len(data)),1):
    s1 = data[i]["交易日期"]
    s2 = data[i]["作物名稱"]
    s3 = data[i]["市場名稱"]
    s4 = data[i]["平均價"]
    s5 = data[i]["交易量"]
    print( s1 + " " + s2 + " " + s3+ " " + str(s4) + " " + str(s5))
# Out:
# 107.01.19 OT多娜托-三朵 台北市場 65.4 133.0
# 107.01.19 OT多娜托-多朵 台北市場 91.7 408.0
# 107.01.19 OT多娜托-雙朵 台北市場 57.9 59.0
# 107.01.19 OT曼尼薩-三朵 台北市場 305.0 5.0
# 107.01.19 OT曼尼薩-單朵 台北市場 56.5 233.0
# 107.01.19 OT曼尼薩-多朵 台北市場 281.0 10.0
# 107.01.19 OT曼尼薩-雙朵 台北市場 78.3 106.0
# 107.01.19 OT羅賓娜-三朵 台北市場 88.7 36.0
# 107.01.19 OT羅賓娜-多朵 台北市場 103.6 61.0
# 107.01.19 七里香-七里香 台北市場 12.5 91.0
# 107.01.19 九層塔 台北二 83.7 730.0
# 107.01.19 九層塔 台北一 59.5 2002.0
# 107.01.19 九層塔 板橋區 47.6 184.0
# 107.01.19 九層塔 三重區 58.4 22.0
# 107.01.19 九層塔 宜蘭市 38.0 2450.0
# 107.01.19 九層塔 台中市 53.5 94.0
# 107.01.19 九層塔 豐原區 66.0 35.0
# 107.01.19 九層塔 高雄市 72.3 190.0
# 107.01.19 九層塔 屏東市 43.3 72.0
# 107.01.19 休市 鳳山區 0.0 0.0
# 107.01.19 伯利恆之星-伯利恆之星 台北市場 25.5 640.0
# 107.01.19 佛利檬-佛利檬 台北二 28.7 180.0
# 107.01.19 佛利檬-佛利檬 台北一 33.9 392.0
# 107.01.19 佛利檬-佛利檬 板橋區 20.0 100.0
# 107.01.19 佛利檬-佛利檬 三重區 34.1 332.0
# 107.01.19 佛利檬-佛利檬 台中市 37.7 168.0
# 107.01.19 八角金盤-八角金盤 台北市場 27.8 250.0
# 107.01.19 其他 台北二 87.0 121.0
# 107.01.19 其他 台北一 92.8 294.0
# ...
